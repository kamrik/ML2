# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import scipy
from scipy import signal
from scipy import misc
from scipy import ndimage

# %% [markdown]
# ## COMP 3132 -  Machine Learning with Python
# __Week 2 lecture__
#
# ### [github.com/kamrik/ML2](https://github.com/kamrik/ML2)
#
# ### [slido.com/COMP3132](http://slido.com/COMP3132)

# %% [markdown]
# ## Plan for today
#  - Administrative
#  - Convolution
#  - Neural net anatomy in more detail

# %% [markdown]
# ## Home assignment 1 is due next week
#  - All details on GitHub

# %% [markdown]
# ## Slack: GeorgeBrownTech
# ![slack](https://assets.brandfolder.com/c8d4sd15/original/slack_rgb.png?_ga=2.157680697.224843471.1547563140-1690239087.1547563140)

# %% [markdown]
# ## Convolutions

# %% [markdown]
# ![convolution](https://www.researchgate.net/profile/Alistair_Mcewan2/publication/255564269/figure/fig1/AS:297866045214735@1448028207647/Convolution-of-a-radius-1-1D-filter-and-an-8-element-input-array-with-one-operation.png)

# %%
noisy = np.sin(np.arange(60)/3) + np.random.randn(60)/3
plt.plot(noisy, '.-')
plt.grid()

# %%
kernel = np.ones(3)/3
smoothed = np.convolve(noisy, kernel, 'same')

# %%
plt.plot(noisy, '.-')
plt.plot(smoothed, '.-')
plt.grid()

# %%
plt.plot(noisy, '.-', label='raw')
for window in [5,15]:
    k = np.ones(window)/window
    plt.plot(np.convolve(noisy, k, 'same'), '.-', label=str(window))
plt.legend()
plt.grid()

# %% [markdown]
# ## What's the `same` parameter?

# %%
smoothed = np.convolve(noisy, kernel, 'same')

# %% [markdown]
# ## Neuron in a neural network
# ![neuron](https://naadispeaks.files.wordpress.com/2017/11/vqope.jpg?w=630)

# %% [markdown]
# ![learning](learning_dagram_fig3_1.png)
# Figure 3.1, from the [book](https://www.manning.com/books/deep-learning-with-python)
